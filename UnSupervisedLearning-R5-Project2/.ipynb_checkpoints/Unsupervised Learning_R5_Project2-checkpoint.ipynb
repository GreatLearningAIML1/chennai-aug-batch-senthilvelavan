# %% [markdown]
# <h1>Unsupervised Learning_R5_Project2</h1>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
veh_df = pd.read_csv('vehicle.csv')
veh_df.head(10)
# Out:
#    compactness  circularity  distance_circularity  radius_ratio  \
# 0           95         48.0                  83.0         178.0
# 1           91         41.0                  84.0         141.0
# 2          104         50.0                 106.0         209.0
# 3           93         41.0                  82.0         159.0
# 4           85         44.0                  70.0         205.0
# 5          107          NaN                 106.0         172.0
# 6           97         43.0                  73.0         173.0
# 7           90         43.0                  66.0         157.0
# 8           86         34.0                  62.0         140.0
# 9           93         44.0                  98.0           NaN
#
#    pr.axis_aspect_ratio  max.length_aspect_ratio  scatter_ratio  \
# 0                  72.0                       10          162.0
# 1                  57.0                        9          149.0
# 2                  66.0                       10          207.0
# ...

# %% [markdown]
# <h2>1. Data pre-processing - Understand the data and treat missing values (Use box plot), outliers (5 points)</h2>

# %%
veh_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 846 entries, 0 to 845
# Data columns (total 19 columns):
# compactness                    846 non-null int64
# circularity                    841 non-null float64
# distance_circularity           842 non-null float64
# radius_ratio                   840 non-null float64
# pr.axis_aspect_ratio           844 non-null float64
# max.length_aspect_ratio        846 non-null int64
# scatter_ratio                  845 non-null float64
# elongatedness                  845 non-null float64
# pr.axis_rectangularity         843 non-null float64
# max.length_rectangularity      846 non-null int64
# scaled_variance                843 non-null float64
# scaled_variance.1              844 non-null float64
# scaled_radius_of_gyration      844 non-null float64
# scaled_radius_of_gyration.1    842 non-null float64
# skewness_about                 840 non-null float64
# skewness_about.1               845 non-null float64
# ...

# %%
sns.heatmap(veh_df.isnull())

# %% [markdown]
# <h3>Imputation for na values in column circularity</h3>

# %%
veh_df[veh_df['circularity'].isnull()]
# Out:
#      compactness  circularity  distance_circularity  radius_ratio  \
# 5            107          NaN                 106.0         172.0
# 105          108          NaN                 103.0         202.0
# 118           85          NaN                   NaN         128.0
# 266           86          NaN                  65.0         116.0
# 396          108          NaN                 106.0         177.0
#
#      pr.axis_aspect_ratio  max.length_aspect_ratio  scatter_ratio  \
# 5                    50.0                        6          255.0
# 105                  64.0                       10          220.0
# 118                  56.0                        8          150.0
# 266                  53.0                        6          152.0
# 396                  51.0                        5          256.0
#
#      elongatedness  pr.axis_rectangularity  max.length_rectangularity  \
# 5             26.0                    28.0                        169
# ...

# %%
sns.boxplot(veh_df['circularity'])

# %%
veh_df['circularity'].fillna(veh_df[~veh_df['circularity'].isna()]['circularity'].median(), inplace=True)

# %%
veh_df[veh_df['circularity'].isnull()]
# Out:
# Empty DataFrame
# Columns: [compactness, circularity, distance_circularity, radius_ratio, pr.axis_aspect_ratio, max.length_aspect_ratio, scatter_ratio, elongatedness, pr.axis_rectangularity, max.length_rectangularity, scaled_variance, scaled_variance.1, scaled_radius_of_gyration, scaled_radius_of_gyration.1, skewness_about, skewness_about.1, skewness_about.2, hollows_ratio, class]
# Index: []

# %% [markdown]
# <h3>Imputation of na values for distance_circularity </h3>

# %%
veh_df[veh_df['distance_circularity'].isnull()]
# Out:
#      compactness  circularity  distance_circularity  radius_ratio  \
# 35           100         46.0                   NaN         172.0
# 118           85         44.0                   NaN         128.0
# 207           85         42.0                   NaN         121.0
# 319          102         51.0                   NaN         194.0
#
#      pr.axis_aspect_ratio  max.length_aspect_ratio  scatter_ratio  \
# 35                   67.0                        9          157.0
# 118                  56.0                        8          150.0
# 207                  55.0                        7          149.0
# 319                  60.0                        6          220.0
#
#      elongatedness  pr.axis_rectangularity  max.length_rectangularity  \
# 35            43.0                    20.0                        150
# 118           46.0                    19.0                        144
# 207           46.0                    19.0                        146
# ...

# %%
sns.boxplot(veh_df['distance_circularity'])

# %%
veh_df[~veh_df['distance_circularity'].isna()]['distance_circularity'].median()
# Out:
# 80.0

# %%
veh_df['distance_circularity'].fillna(veh_df[~veh_df['distance_circularity'].isna()]['distance_circularity'].median(),inplace=True)

# %%
veh_df[veh_df['distance_circularity'].isnull()]
# Out:
# Empty DataFrame
# Columns: [compactness, circularity, distance_circularity, radius_ratio, pr.axis_aspect_ratio, max.length_aspect_ratio, scatter_ratio, elongatedness, pr.axis_rectangularity, max.length_rectangularity, scaled_variance, scaled_variance.1, scaled_radius_of_gyration, scaled_radius_of_gyration.1, skewness_about, skewness_about.1, skewness_about.2, hollows_ratio, class]
# Index: []

# %% [markdown]
# <h3>Imputation of na values for radius_ratio</h3>

# %%
veh_df[veh_df['radius_ratio'].isnull()]
# Out:
#      compactness  circularity  distance_circularity  radius_ratio  \
# 9             93         44.0                  98.0           NaN
# 78           104         52.0                  94.0           NaN
# 159           91         45.0                  75.0           NaN
# 287           88         43.0                  84.0           NaN
# 345          101         54.0                 106.0           NaN
# 467           96         54.0                 104.0           NaN
#
#      pr.axis_aspect_ratio  max.length_aspect_ratio  scatter_ratio  \
# 9                    62.0                       11          183.0
# 78                   66.0                        5          208.0
# 159                  57.0                        6          150.0
# 287                  55.0                       11          154.0
# 345                  57.0                        7          236.0
# 467                  58.0                       10          215.0
#
# ...

# %%
sns.boxplot(veh_df['radius_ratio'])

# %%
veh_df[~veh_df['radius_ratio'].isnull()]['radius_ratio'].median()
# Out:
# 167.0

# %%
veh_df['radius_ratio'].fillna(veh_df[~veh_df['radius_ratio'].isnull()]['radius_ratio'].median(), inplace=True)

# %%
veh_df[veh_df['radius_ratio'].isnull()]
# Out:
# Empty DataFrame
# Columns: [compactness, circularity, distance_circularity, radius_ratio, pr.axis_aspect_ratio, max.length_aspect_ratio, scatter_ratio, elongatedness, pr.axis_rectangularity, max.length_rectangularity, scaled_variance, scaled_variance.1, scaled_radius_of_gyration, scaled_radius_of_gyration.1, skewness_about, skewness_about.1, skewness_about.2, hollows_ratio, class]
# Index: []

# %% [markdown]
# <h3>Imputation of na values for column pr.axis_aspect_ratio</h3>

# %%
veh_df[veh_df['pr.axis_aspect_ratio'].isnull()]
# Out:
#      compactness  circularity  distance_circularity  radius_ratio  \
# 19           101         56.0                 100.0         215.0
# 222          100         50.0                  81.0         197.0
#
#      pr.axis_aspect_ratio  max.length_aspect_ratio  scatter_ratio  \
# 19                    NaN                       10          208.0
# 222                   NaN                        6          186.0
#
#      elongatedness  pr.axis_rectangularity  max.length_rectangularity  \
# 19            32.0                    24.0                        169
# 222           34.0                    22.0                        158
#
#      scaled_variance  scaled_variance.1  scaled_radius_of_gyration  \
# 19             227.0              651.0                      223.0
# 222            206.0              531.0                      198.0
#
#      scaled_radius_of_gyration.1  skewness_about  skewness_about.1  \
# 19                          74.0             6.0               5.0
# ...

# %%
sns.boxplot(veh_df['pr.axis_aspect_ratio'])

# %%
veh_df[~veh_df['pr.axis_aspect_ratio'].isnull()]['pr.axis_aspect_ratio'].median()
# Out:
# 61.0

# %%
veh_df['pr.axis_aspect_ratio'].fillna(veh_df[~veh_df['pr.axis_aspect_ratio'].isnull()]['pr.axis_aspect_ratio'].median(),inplace=True)

# %%
veh_df[veh_df['pr.axis_aspect_ratio'].isnull()]
# Out:
# Empty DataFrame
# Columns: [compactness, circularity, distance_circularity, radius_ratio, pr.axis_aspect_ratio, max.length_aspect_ratio, scatter_ratio, elongatedness, pr.axis_rectangularity, max.length_rectangularity, scaled_variance, scaled_variance.1, scaled_radius_of_gyration, scaled_radius_of_gyration.1, skewness_about, skewness_about.1, skewness_about.2, hollows_ratio, class]
# Index: []

# %% [markdown]
# <h3>Imputation of na values in column scatter_ratio</h3>

# %%
veh_df[veh_df['scatter_ratio'].isnull()]
# Out:
#      compactness  circularity  distance_circularity  radius_ratio  \
# 249           85         34.0                  53.0         127.0
#
#      pr.axis_aspect_ratio  max.length_aspect_ratio  scatter_ratio  \
# 249                  58.0                        6            NaN
#
#      elongatedness  pr.axis_rectangularity  max.length_rectangularity  \
# 249           58.0                    17.0                        121
#
#      scaled_variance  scaled_variance.1  scaled_radius_of_gyration  \
# 249            137.0              197.0                      127.0
#
#      scaled_radius_of_gyration.1  skewness_about  skewness_about.1  \
# 249                         70.0             NaN              20.0
#
#      skewness_about.2  hollows_ratio class
# 249             185.0            189   car

# %%
sns.boxplot(veh_df['scatter_ratio'])

# %%
veh_df[~veh_df['scatter_ratio'].isnull()]['scatter_ratio'].median()
# Out:
# 157.0

# %%
veh_df['scatter_ratio'].fillna(veh_df[~veh_df['scatter_ratio'].isnull()]['scatter_ratio'].median(), inplace=True)

# %%
veh_df[veh_df['scatter_ratio'].isnull()]
# Out:
# Empty DataFrame
# Columns: [compactness, circularity, distance_circularity, radius_ratio, pr.axis_aspect_ratio, max.length_aspect_ratio, scatter_ratio, elongatedness, pr.axis_rectangularity, max.length_rectangularity, scaled_variance, scaled_variance.1, scaled_radius_of_gyration, scaled_radius_of_gyration.1, skewness_about, skewness_about.1, skewness_about.2, hollows_ratio, class]
# Index: []

# %% [markdown]
# <h3>Imputation of na values in column elongatedness</h3>

# %%
veh_df[veh_df['elongatedness'].isnull()]
# Out:
#      compactness  circularity  distance_circularity  radius_ratio  \
# 215           90         39.0                  86.0         169.0
#
#      pr.axis_aspect_ratio  max.length_aspect_ratio  scatter_ratio  \
# 215                  62.0                        7          162.0
#
#      elongatedness  pr.axis_rectangularity  max.length_rectangularity  \
# 215            NaN                    20.0                        131
#
#      scaled_variance  scaled_variance.1  scaled_radius_of_gyration  \
# 215            194.0              388.0                      147.0
#
#      scaled_radius_of_gyration.1  skewness_about  skewness_about.1  \
# 215                         74.0             1.0              22.0
#
#      skewness_about.2  hollows_ratio class
# 215             185.0            191   car

# %%
sns.boxplot(veh_df['elongatedness'])

# %%
veh_df[~veh_df['elongatedness'].isnull()]['elongatedness'].median()
# Out:
# 43.0

# %%
veh_df['elongatedness'].fillna(veh_df[~veh_df['elongatedness'].isnull()]['elongatedness'].median(), inplace=True)

# %%
veh_df[veh_df['elongatedness'].isnull()]
# Out:
# Empty DataFrame
# Columns: [compactness, circularity, distance_circularity, radius_ratio, pr.axis_aspect_ratio, max.length_aspect_ratio, scatter_ratio, elongatedness, pr.axis_rectangularity, max.length_rectangularity, scaled_variance, scaled_variance.1, scaled_radius_of_gyration, scaled_radius_of_gyration.1, skewness_about, skewness_about.1, skewness_about.2, hollows_ratio, class]
# Index: []

# %% [markdown]
# <h3>Imputation of na values for column pr.axis_rectangularity</h3>

# %%
veh_df[veh_df['pr.axis_rectangularity'].isnull()]
# Out:
#      compactness  circularity  distance_circularity  radius_ratio  \
# 70            96         55.0                  98.0         161.0
# 237           85         45.0                  65.0         128.0
# 273           96         45.0                  80.0         162.0
#
#      pr.axis_aspect_ratio  max.length_aspect_ratio  scatter_ratio  \
# 70                   54.0                       10          215.0
# 237                  56.0                        8          151.0
# 273                  63.0                        9          146.0
#
#      elongatedness  pr.axis_rectangularity  max.length_rectangularity  \
# 70            31.0                     NaN                        175
# 237           45.0                     NaN                        145
# 273           46.0                     NaN                        148
#
#      scaled_variance  scaled_variance.1  scaled_radius_of_gyration  \
# 70             226.0              683.0                      221.0
# ...

# %%
sns.boxplot(veh_df['pr.axis_rectangularity'])

# %%
veh_df[~veh_df['pr.axis_rectangularity'].isnull()]['pr.axis_rectangularity'].median()
# Out:
# 20.0

# %%
veh_df['pr.axis_rectangularity'].fillna(veh_df[~veh_df['pr.axis_rectangularity'].isnull()]['pr.axis_rectangularity'].median(), inplace=True)

# %%
veh_df[veh_df['pr.axis_rectangularity'].isnull()]
# Out:
# Empty DataFrame
# Columns: [compactness, circularity, distance_circularity, radius_ratio, pr.axis_aspect_ratio, max.length_aspect_ratio, scatter_ratio, elongatedness, pr.axis_rectangularity, max.length_rectangularity, scaled_variance, scaled_variance.1, scaled_radius_of_gyration, scaled_radius_of_gyration.1, skewness_about, skewness_about.1, skewness_about.2, hollows_ratio, class]
# Index: []

# %% [markdown]
# <h3>Imputation of na values for column scaled_variance</h3>

# %%
veh_df[veh_df['scaled_variance'].isnull()]
# Out:
#      compactness  circularity  distance_circularity  radius_ratio  \
# 105          108         44.0                 103.0         202.0
# 372           97         47.0                  87.0         164.0
# 522           89         36.0                  69.0         162.0
#
#      pr.axis_aspect_ratio  max.length_aspect_ratio  scatter_ratio  \
# 105                  64.0                       10          220.0
# 372                  64.0                        9          156.0
# 522                  63.0                        6          140.0
#
#      elongatedness  pr.axis_rectangularity  max.length_rectangularity  \
# 105           30.0                    25.0                        168
# 372           43.0                    20.0                        149
# 522           48.0                    18.0                        131
#
#      scaled_variance  scaled_variance.1  scaled_radius_of_gyration  \
# 105              NaN              711.0                      214.0
# ...

# %%
sns.boxplot(veh_df['scaled_variance'])

# %%
veh_df[~veh_df['scaled_variance'].isnull()]['scaled_variance'].median()
# Out:
# 179.0

# %%
veh_df['scaled_variance'].fillna(veh_df[~veh_df['scaled_variance'].isnull()]['scaled_variance'].median(), inplace=True)

# %%
veh_df[veh_df['scaled_variance'].isnull()]
# Out:
# Empty DataFrame
# Columns: [compactness, circularity, distance_circularity, radius_ratio, pr.axis_aspect_ratio, max.length_aspect_ratio, scatter_ratio, elongatedness, pr.axis_rectangularity, max.length_rectangularity, scaled_variance, scaled_variance.1, scaled_radius_of_gyration, scaled_radius_of_gyration.1, skewness_about, skewness_about.1, skewness_about.2, hollows_ratio, class]
# Index: []

# %% [markdown]
# <h3>Imputation of na values for column scaled_variance.1</h3>

# %%
veh_df[veh_df['scaled_variance.1'].isnull()]
# Out:
#      compactness  circularity  distance_circularity  radius_ratio  \
# 308          109         51.0                 100.0         197.0
# 496          106         55.0                  98.0         224.0
#
#      pr.axis_aspect_ratio  max.length_aspect_ratio  scatter_ratio  \
# 308                  59.0                       10          192.0
# 496                  68.0                       11          215.0
#
#      elongatedness  pr.axis_rectangularity  max.length_rectangularity  \
# 308           34.0                    22.0                        161
# 496           31.0                    24.0                        170
#
#      scaled_variance  scaled_variance.1  scaled_radius_of_gyration  \
# 308            210.0                NaN                      195.0
# 496            222.0                NaN                      214.0
#
#      scaled_radius_of_gyration.1  skewness_about  skewness_about.1  \
# 308                         64.0            14.0               3.0
# ...

# %%
sns.boxplot(veh_df['scaled_variance.1'])

# %%
veh_df[~veh_df['scaled_variance.1'].isnull()]['scaled_variance.1'].median()
# Out:
# 363.5

# %%
veh_df['scaled_variance.1'].fillna(veh_df[~veh_df['scaled_variance.1'].isnull()]['scaled_variance.1'].median(), inplace=True)

# %%
veh_df[veh_df['scaled_variance.1'].isnull()]
# Out:
# Empty DataFrame
# Columns: [compactness, circularity, distance_circularity, radius_ratio, pr.axis_aspect_ratio, max.length_aspect_ratio, scatter_ratio, elongatedness, pr.axis_rectangularity, max.length_rectangularity, scaled_variance, scaled_variance.1, scaled_radius_of_gyration, scaled_radius_of_gyration.1, skewness_about, skewness_about.1, skewness_about.2, hollows_ratio, class]
# Index: []

# %% [markdown]
# <h3>Imputation of na values for column scaled_radius_of_gyration</h3>

# %%
veh_df[veh_df['scaled_radius_of_gyration'].isnull()]
# Out:
#      compactness  circularity  distance_circularity  radius_ratio  \
# 207           85         42.0                   NaN         121.0
# 266           86         44.0                  65.0         116.0
#
#      pr.axis_aspect_ratio  max.length_aspect_ratio  scatter_ratio  \
# 207                  55.0                        7          149.0
# 266                  53.0                        6          152.0
#
#      elongatedness  pr.axis_rectangularity  max.length_rectangularity  \
# 207           46.0                    19.0                        146
# 266           45.0                    19.0                        141
#
#      scaled_variance  scaled_variance.1  scaled_radius_of_gyration  \
# 207            167.0              323.0                        NaN
# 266            175.0              335.0                        NaN
#
#      scaled_radius_of_gyration.1  skewness_about  skewness_about.1  \
# 207                         85.0             1.0               6.0
# ...

# %%
sns.boxplot(veh_df['scaled_radius_of_gyration'])

# %%
veh_df[~veh_df['scaled_radius_of_gyration'].isnull()]['scaled_radius_of_gyration'].median()
# Out:
# 173.5

# %%
veh_df['scaled_radius_of_gyration'].fillna(veh_df[~veh_df['scaled_radius_of_gyration'].isnull()]['scaled_radius_of_gyration'].median(), inplace=True)

# %%
veh_df[veh_df['scaled_radius_of_gyration'].isnull()]
# Out:
# Empty DataFrame
# Columns: [compactness, circularity, distance_circularity, radius_ratio, pr.axis_aspect_ratio, max.length_aspect_ratio, scatter_ratio, elongatedness, pr.axis_rectangularity, max.length_rectangularity, scaled_variance, scaled_variance.1, scaled_radius_of_gyration, scaled_radius_of_gyration.1, skewness_about, skewness_about.1, skewness_about.2, hollows_ratio, class]
# Index: []

# %% [markdown]
# <h3>Imputation of na values for column scaled_radius_of_gyration.1</h3>

# %%
veh_df[veh_df['scaled_radius_of_gyration.1'].isnull()]
# Out:
#      compactness  circularity  distance_circularity  radius_ratio  \
# 66            81         43.0                  68.0         125.0
# 77            86         40.0                  62.0         140.0
# 192           93         43.0                  76.0         149.0
# 329           89         38.0                  80.0         169.0
#
#      pr.axis_aspect_ratio  max.length_aspect_ratio  scatter_ratio  \
# 66                   57.0                        8          149.0
# 77                   62.0                        7          150.0
# 192                  57.0                        7          149.0
# 329                  59.0                        7          161.0
#
#      elongatedness  pr.axis_rectangularity  max.length_rectangularity  \
# 66            46.0                    19.0                        146
# 77            45.0                    19.0                        133
# 192           44.0                    19.0                        143
# ...

# %%
sns.boxplot(veh_df['scaled_radius_of_gyration.1'])

# %%
veh_df[~veh_df['scaled_radius_of_gyration.1'].isnull()]['scaled_radius_of_gyration.1'].median()
# Out:
# 71.5

# %%
veh_df['scaled_radius_of_gyration.1'].fillna(veh_df[~veh_df['scaled_radius_of_gyration.1'].isnull()]['scaled_radius_of_gyration.1'].median(), inplace=True)

# %%
veh_df[veh_df['scaled_radius_of_gyration.1'].isnull()]
# Out:
# Empty DataFrame
# Columns: [compactness, circularity, distance_circularity, radius_ratio, pr.axis_aspect_ratio, max.length_aspect_ratio, scatter_ratio, elongatedness, pr.axis_rectangularity, max.length_rectangularity, scaled_variance, scaled_variance.1, scaled_radius_of_gyration, scaled_radius_of_gyration.1, skewness_about, skewness_about.1, skewness_about.2, hollows_ratio, class]
# Index: []

# %% [markdown]
# <h3>Imputation of na values for column skewness_about</h3>

# %%
veh_df[veh_df['skewness_about'].isnull()]
# Out:
#      compactness  circularity  distance_circularity  radius_ratio  \
# 66            81         43.0                  68.0         125.0
# 141           81         42.0                  63.0         125.0
# 177           89         44.0                  72.0         160.0
# 222          100         50.0                  81.0         197.0
# 249           85         34.0                  53.0         127.0
# 285           89         48.0                  85.0         189.0
#
#      pr.axis_aspect_ratio  max.length_aspect_ratio  scatter_ratio  \
# 66                   57.0                        8          149.0
# 141                  55.0                        8          149.0
# 177                  66.0                        7          144.0
# 222                   NaN                        6          186.0
# 249                  58.0                        6            NaN
# 285                  64.0                        8          169.0
#
# ...

# %%
sns.boxplot(veh_df['skewness_about'])

# %%
veh_df[~veh_df['skewness_about'].isnull()]['skewness_about'].median()
# Out:
# 6.0

# %%
veh_df['skewness_about'].fillna(veh_df[~veh_df['skewness_about'].isnull()]['skewness_about'].median(), inplace=True)

# %%
veh_df[veh_df['skewness_about'].isnull()]
# Out:
# Empty DataFrame
# Columns: [compactness, circularity, distance_circularity, radius_ratio, pr.axis_aspect_ratio, max.length_aspect_ratio, scatter_ratio, elongatedness, pr.axis_rectangularity, max.length_rectangularity, scaled_variance, scaled_variance.1, scaled_radius_of_gyration, scaled_radius_of_gyration.1, skewness_about, skewness_about.1, skewness_about.2, hollows_ratio, class]
# Index: []

# %% [markdown]
# <h3>Imputaton of na values for column skewness_about.1</h3>

# %%
veh_df[veh_df['skewness_about.1'].isnull()]
# Out:
#      compactness  circularity  distance_circularity  radius_ratio  \
# 105          108         44.0                 103.0         202.0
#
#      pr.axis_aspect_ratio  max.length_aspect_ratio  scatter_ratio  \
# 105                  64.0                       10          220.0
#
#      elongatedness  pr.axis_rectangularity  max.length_rectangularity  \
# 105           30.0                    25.0                        168
#
#      scaled_variance  scaled_variance.1  scaled_radius_of_gyration  \
# 105              NaN              711.0                      214.0
#
#      scaled_radius_of_gyration.1  skewness_about  skewness_about.1  \
# 105                         73.0            11.0               NaN
#
#      skewness_about.2  hollows_ratio class
# 105             188.0            199   car

# %%
sns.boxplot(veh_df['skewness_about.1'])

# %%
veh_df[~veh_df['skewness_about.1'].isnull()]['skewness_about.1'].median()
# Out:
# 11.0

# %%
veh_df['skewness_about.1'].fillna(veh_df[~veh_df['skewness_about.1'].isnull()]['skewness_about.1'].median(), inplace=True)

# %%
veh_df[veh_df['skewness_about.1'].isnull()]
# Out:
# Empty DataFrame
# Columns: [compactness, circularity, distance_circularity, radius_ratio, pr.axis_aspect_ratio, max.length_aspect_ratio, scatter_ratio, elongatedness, pr.axis_rectangularity, max.length_rectangularity, scaled_variance, scaled_variance.1, scaled_radius_of_gyration, scaled_radius_of_gyration.1, skewness_about, skewness_about.1, skewness_about.2, hollows_ratio, class]
# Index: []

# %% [markdown]
# <h3>Imputation of na values for column skewness_about.2</h3>

# %%
veh_df[veh_df['skewness_about.2'].isnull()]
# Out:
#      compactness  circularity  distance_circularity  radius_ratio  \
# 419           93         34.0                  72.0         144.0
#
#      pr.axis_aspect_ratio  max.length_aspect_ratio  scatter_ratio  \
# 419                  56.0                        6          133.0
#
#      elongatedness  pr.axis_rectangularity  max.length_rectangularity  \
# 419           50.0                    18.0                        123
#
#      scaled_variance  scaled_variance.1  scaled_radius_of_gyration  \
# 419            158.0              263.0                      125.0
#
#      scaled_radius_of_gyration.1  skewness_about  skewness_about.1  \
# 419                         63.0             5.0              20.0
#
#      skewness_about.2  hollows_ratio class
# 419               NaN            206   car

# %%
sns.boxplot(veh_df['skewness_about.2'])

# %%
veh_df[~veh_df['skewness_about.2'].isnull()]['skewness_about.2'].median()
# Out:
# 188.0

# %%
veh_df['skewness_about.2'].fillna(veh_df[~veh_df['skewness_about.2'].isnull()]['skewness_about.2'].median(), inplace=True)

# %%
veh_df[veh_df['skewness_about.2'].isnull()]
# Out:
# Empty DataFrame
# Columns: [compactness, circularity, distance_circularity, radius_ratio, pr.axis_aspect_ratio, max.length_aspect_ratio, scatter_ratio, elongatedness, pr.axis_rectangularity, max.length_rectangularity, scaled_variance, scaled_variance.1, scaled_radius_of_gyration, scaled_radius_of_gyration.1, skewness_about, skewness_about.1, skewness_about.2, hollows_ratio, class]
# Index: []

# %% [markdown]
# <h3>Analysis of column hollows_ratio</h3>

# %%
veh_df[veh_df['hollows_ratio'].isnull()]
# Out:
# Empty DataFrame
# Columns: [compactness, circularity, distance_circularity, radius_ratio, pr.axis_aspect_ratio, max.length_aspect_ratio, scatter_ratio, elongatedness, pr.axis_rectangularity, max.length_rectangularity, scaled_variance, scaled_variance.1, scaled_radius_of_gyration, scaled_radius_of_gyration.1, skewness_about, skewness_about.1, skewness_about.2, hollows_ratio, class]
# Index: []

# %%
sns.boxplot(veh_df['hollows_ratio'])

# %% [markdown]
# <h3>Analysis of column class</h3>

# %%
veh_df[veh_df['class'].isnull()]
# Out:
# Empty DataFrame
# Columns: [compactness, circularity, distance_circularity, radius_ratio, pr.axis_aspect_ratio, max.length_aspect_ratio, scatter_ratio, elongatedness, pr.axis_rectangularity, max.length_rectangularity, scaled_variance, scaled_variance.1, scaled_radius_of_gyration, scaled_radius_of_gyration.1, skewness_about, skewness_about.1, skewness_about.2, hollows_ratio, class]
# Index: []

# %%
veh_df.boxplot(by='class',figsize=(10,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001B1753D2E80>,
# ...
#       dtype=object)

# %%
sns.countplot(x='class',data=veh_df)

# %%
veh_df['class'].value_counts()
# Out:
# car    429
# bus    218
# van    199
# Name: class, dtype: int64

# %%
sns.heatmap(veh_df.isnull())

# %% [markdown]
# <h2>2. Understanding the attributes - Find relationship between different attributes (Independent variables) and choose carefully which all attributes have to be a part of the analysis and why (5 points)</h2>

# %% [markdown]
# <h2>3. Use PCA from scikit learn and elbow plot to find out reduced number of dimension (which covers more than 95% of the variance) - 10 points</h2>

# %% [markdown]
# <h2>4. Use Support vector machines and use grid search (try C values - 0.01, 0.05, 0.5, 1 and kernel = linear, rbf) and find out the best hyper parameters and do cross validation to find the accuracy. (10 points)</h2>
